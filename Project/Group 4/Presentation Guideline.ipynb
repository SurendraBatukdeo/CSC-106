# %% [markdown]
# # Group 1

# %% [markdown]
# Team members : Jacob Duppong
#                Alonso Gutierrez
#                Thomas King

# %% [markdown]
# # Introduction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import Image

# %%
Image('PredatorPreyIdeal.png')

# %% [markdown]
# Text : This is the ideal

# %% [markdown]
# # Input

# %%
Describe your data

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
year=[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2023,2024]
wolf=[19,32,42,35,65,70,78,98,84,75,94,57,40,38,38,34,42,50,41,33,39,55,79,50,55,69]
elk=[133.91,117.36,117.42,145.39,134.00,119.69,92.15,83.35,95.45,67.38,62.79,71.09,60.70,46.35,41.74,39.15,48.44,49.12,53.49,75.79,58.00,60.19,62.46,66.73,66.51,55.97]

plt.plot(year,wolf)
plt.plot(year,elk)

plt.xlabel("Year")  # add X-axis label
plt.ylabel("Population")  # add Y-axis label
plt.title("Population Counts")  # add title
plt.show()

# %%
import pandas as pd
df={"Year":year,"Wolves":wolf,"Elk (Hundreds)":elk}
pd.DataFrame(df)
# Out:
#     Year  Wolves  Elk (Hundreds)
# 0   1998      19          133.91
# 1   1999      32          117.36
# 2   2000      42          117.42
# 3   2001      35          145.39
# 4   2002      65          134.00
# 5   2003      70          119.69
# 6   2004      78           92.15
# 7   2005      98           83.35
# 8   2006      84           95.45
# 9   2007      75           67.38
# 10  2008      94           62.79
# 11  2009      57           71.09
# 12  2010      40           60.70
# 13  2011      38           46.35
# 14  2012      38           41.74
# 15  2013      34           39.15
# 16  2014      42           48.44
# 17  2015      50           49.12
# 18  2016      41           53.49
# 19  2017      33           75.79
# 20  2018      39           58.00
# 21  2019      55           60.19
# 22  2020      79           62.46
# 23  2021      50           66.73
# 24  2023      55           66.51
# 25  2024      69           55.97

# %% [markdown]
# # Process

# %% [markdown]
# Explain the process with an example

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
wolf=[19,32,42,35,65,70,78,98,84,75,94,57,40,38,38,34,42,50,41,33,39,55,79,50,55,69]
elk=[133.91,117.36,117.42,145.39,134.00,119.69,92.15,83.35,95.45,67.38,62.79,71.09,60.70,46.35,41.74,39.15,48.44,49.12,53.49,75.79,58.00,60.19,62.46,66.73,66.51,55.97]
plt.plot(wolf,elk)

# %% [markdown]
# # Output

# %%
Explain using Inputand Output

# %%
Image('sim.png')

# %% [markdown]
# # Conclusion

# %%
Lesson Learnt

# %% [raw]
# More than one predators, external factors
